# %%
import zipfile
import os

# Assuming the zip file is uploaded or located at 'filename.zip'
zip_file_path = '/content/drive/MyDrive/Main Project 1/helmet-detection.v10i.yolov5pytorch.zip'  # Modify this to your zip file's path
extract_dir = '/content/drive/MyDrive/Main Project 1'  # Directory where the contents will be extracted

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List extracted files
print(os.listdir(extract_dir))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4962c6824e02> in <cell line: 0>()
#       7
#       8 # Unzip the file
# ----> 9 with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#      10     zip_ref.extractall(extract_dir)
#      11
#
# /usr/lib/python3.11/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1293             while True:
#    1294                 try:
# -> 1295                     self.fp = io.open(file, filemode)
#    1296                 except OSError:
#    1297                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Main Project 1/helmet-detection.v10i.yolov5pytorch.zip'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone the YOLOv5 repository from GitHub
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# Install dependencies
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17265 (from 1)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 16.43 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.8 MB/s eta 0:00:00
# ...

# %%
# Assuming the data.yaml file is located in the /content/dataset directory
with open('/content/drive/MyDrive/MainProject1/data.yaml', 'r') as file:
    data_yaml_content = file.read()

print(data_yaml_content)
# Out:
# names:
# - bicyclist
# - driver
# - helmet
# - no-helmet
# - notsure
# nc: 5
# roboflow:
#   license: CC BY 4.0
#   project: helmet-detection-ntbfz
#   url: https://universe.roboflow.com/imagerecognition-43zpb/helmet-detection-ntbfz/dataset/10
#   version: 10
#   workspace: imagerecognition-43zpb
# test: /content/drive/MyDrive/MainProject1/test/images
# train: /content/drive/MyDrive/MainProject1/train/images
# val: /content/drive/MyDrive/MainProject1/valid/images

# %%
import yaml

# Load the YAML file
with open('/content/drive/MyDrive/MainProject1/data.yaml', 'r') as file:
    data_yaml = yaml.safe_load(file)

# Modify the paths to be compatible with the Colab environment
data_yaml['train'] = '/content/drive/MyDrive/MainProject1/train/images'
data_yaml['val'] = '/content/drive/MyDrive/MainProject1/valid/images'
if 'test' in data_yaml:
    data_yaml['test'] = '/content/drive/MyDrive/MainProject1/test/images'

# Save the modified YAML file
with open('/content/drive/MyDrive/MainProject1/data.yaml', 'w') as file:
    yaml.dump(data_yaml, file)

print("Updated data.yaml:")
print(data_yaml)
# Out:
# Updated data.yaml:
# {'names': ['bicyclist', 'driver', 'helmet', 'no-helmet', 'notsure'], 'nc': 5, 'roboflow': {'license': 'CC BY 4.0', 'project': 'helmet-detection-ntbfz', 'url': 'https://universe.roboflow.com/imagerecognition-43zpb/helmet-detection-ntbfz/dataset/10', 'version': 10, 'workspace': 'imagerecognition-43zpb'}, 'test': '/content/drive/MyDrive/MainProject1/test/images', 'train': '/content/drive/MyDrive/MainProject1/train/images', 'val': '/content/drive/MyDrive/MainProject1/valid/images'}

# %%
train: '/content/drive/MyDrive/MainProject1/train/images'  # Path to training images
val: '/content/drive/MyDrive/MainProject1/valid/images'    # Path to validation images
test: '/content/drive/MyDrive/MainProject1/test/images'    # Path to test images (optional but recommended)

nc: 2  # Number of classes (helmet and no_helmet)
names: ['helmet', 'no_helmet']  # Class names

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data '/content/drive/MyDrive/MainProject1/data.yaml' \
--weights yolov5m.pt --cache --device 0 --optimizer AdamW --save-period 10 --workers 4
# Out:
# Streaming output truncated to the last 5000 lines.
#        8/99      14.4G    0.04223    0.03715   0.009275        291        640:  69% 61/89 [00:52<00:24,  1.13it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      14.4G    0.04227    0.03719   0.009324        323        640:  70% 62/89 [00:53<00:23,  1.14it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        8/99      14.4G    0.04228    0.03727   0.009323        337        640:  71% 63/89 [00:54<00:21,  1.18it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data '/content/drive/MyDrive/MainProject1/data.yaml' --weights yolov5s.pt --cache
# Out:
# 2024-10-23 12:11:42.009495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 12:11:42.334521: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 12:11:42.415864: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data /content/drive/MyDrive/MainProject1/data.yaml --task test
# Out:
# val: data=/content/drive/MyDrive/MainProject1/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.4.1+cu121 CPU
#
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 604, in <module>
#     main(opt)
#   File "/content/yolov5/val.py", line 575, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/val.py", line 270, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 489, in __init__
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data '/content/drive/MyDrive/MainProject1/data.yaml' --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       86/99      4.38G    0.02283    0.02099    0.00261        113        640:  19% 34/178 [00:10<00:48,  2.95it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       86/99      4.38G    0.02291    0.02117    0.00262        183        640:  20% 35/178 [00:10<00:48,  2.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       86/99      4.38G    0.02308     0.0211   0.002605        123        640:  20% 36/178 [00:11<00:57,  2.47it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !ls runs/train/exp/weights/
# Out:
# best.pt  last.pt

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data '/content/drive/MyDrive/MainProject1/data.yaml' --task test
# Out:
# val: data=/content/drive/MyDrive/MainProject1/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-378-g2f74455a Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/MyDrive/MainProject1/test/labels... 612 images, 1 backgrounds, 0 corrupt: 100% 612/612 [07:34<00:00,  1.35it/s]
# test: New cache created: /content/drive/MyDrive/MainProject1/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:15<00:00,  1.26it/s]
# ...
